# %% [markdown]
# # Step 2 - Test The Model
#
# In this notebook, we will use the model that we trained in Step 1 to drive the car around in AirSim. We will make some observations about the performance of the model, and suggest some potential experiments to improve the model.
#
# First, let us import some libraries.

# %%
from keras.models import load_model
import sys
import numpy as np
import glob
import os

if ('../../PythonClient/' not in sys.path):
    sys.path.insert(0, '../../PythonClient/')
from AirSimClient import *

# << Set this to the path of the model >>
# If None, then the model with the lowest validation loss from training will be used
MODEL_PATH = None

if (MODEL_PATH == None):
    models = glob.glob('model/models/*.h5') 
    best_model = max(models, key=os.path.getctime)
    MODEL_PATH = best_model
    
print('Using model {0} for testing.'.format(MODEL_PATH))
model = load_model(MODEL_PATH)
# Out:
# Using model model/models\model_model.12-0.0002735.h5 for testing.

# %%
print('jaj 223')
# Out:
# jaj 223

# %%
import airsim
client = airsim.CarClient()
client.confirmConnection()
client.enableApiControl(True)
car_controls = airsim.CarControls()
print('Connection established!')
car_controls.steering = 0
car_controls.throttle = 0
car_controls.brake = 0
    # go forward
car_controls.throttle = -0.1
car_controls.steering = 0
client.setCarControls(car_controls)
print("Go Forward now")
#time.sleep(3)   # let car drive a bit
image_buf = np.zeros((1, 59, 255, 3))
state_buf = np.zeros((1,4))
def get_image():
    image_response = client.simGetImages([ImageRequest(0, AirSimImageType.Scene, False, False)])[0]
    image1d = np.fromstring(image_response.image_data_uint8, dtype=np.uint8)
    image_rgba = image1d.reshape(image_response.height, image_response.width, 3)
    
    return image_rgba[76:135,0:255,0:3].astype(float)
while (True):
    car_state = client.getCarState()
    
    if (car_state.speed < 5):
        car_controls.throttle = 1.0
    else:
        car_controls.throttle = 0.0
    
    image_buf[0] = get_image()
    state_buf[0] = np.array([car_controls.steering, car_controls.throttle, car_controls.brake, car_state.speed])
    model_output = model.predict([image_buf, state_buf])
    car_controls.steering = round(0.5 * float(model_output[0][0]), 2)
    
    print('Sending steering = {0}, throttle = {1}'.format(car_controls.steering, car_controls.throttle))
    
    client.setCarControls(car_controls)
# Out:
# Connected!
# Client Ver:1 (Min Req: 1), Server Ver:1 (Min Req: 1)
#
# Connection established!
# Go Forward now
# <ipython-input-3-2f151cb0229a>:20: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   image1d = np.fromstring(image_response.image_data_uint8, dtype=np.uint8)
# Sending steering = -0.22, throttle = 1.0
# Sending steering = -0.28, throttle = 1.0
# Sending steering = -0.3, throttle = 1.0
# Sending steering = -0.31, throttle = 1.0
# Sending steering = -0.31, throttle = 1.0
# Sending steering = -0.32, throttle = 1.0
# Sending steering = -0.28, throttle = 1.0
# Sending steering = -0.21, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.13, throttle = 1.0
# Sending steering = -0.12, throttle = 1.0
# Sending steering = -0.11, throttle = 1.0
# Sending steering = -0.09, throttle = 1.0
# Sending steering = -0.1, throttle = 1.0
# Sending steering = -0.11, throttle = 1.0
# Sending steering = -0.12, throttle = 1.0
# Sending steering = -0.14, throttle = 1.0
# Sending steering = -0.12, throttle = 0.0
# Sending steering = -0.15, throttle = 0.0
# Sending steering = -0.13, throttle = 0.0
# Sending steering = -0.11, throttle = 0.0
# Sending steering = -0.1, throttle = 0.0
# Sending steering = -0.09, throttle = 0.0
# Sending steering = -0.14, throttle = 0.0
# Sending steering = -0.14, throttle = 0.0
# Sending steering = -0.14, throttle = 0.0
# Sending steering = -0.14, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.14, throttle = 0.0
# Sending steering = -0.16, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.13, throttle = 1.0
# Sending steering = -0.12, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.14, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.14, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.2, throttle = 0.0
# Sending steering = -0.23, throttle = 0.0
# Sending steering = -0.23, throttle = 0.0
# Sending steering = -0.24, throttle = 0.0
# Sending steering = -0.24, throttle = 0.0
# Sending steering = -0.29, throttle = 0.0
# Sending steering = -0.26, throttle = 0.0
# Sending steering = -0.2, throttle = 0.0
# Sending steering = -0.3, throttle = 0.0
# Sending steering = -0.35, throttle = 0.0
# Sending steering = -0.3, throttle = 0.0
# Sending steering = -0.2, throttle = 0.0
# Sending steering = -0.24, throttle = 1.0
# Sending steering = -0.3, throttle = 1.0
# Sending steering = -0.23, throttle = 1.0
# Sending steering = -0.2, throttle = 1.0
# Sending steering = 0.01, throttle = 1.0
# Sending steering = -0.04, throttle = 1.0
# Sending steering = -0.1, throttle = 1.0
# Sending steering = 0.05, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.3, throttle = 1.0
# Sending steering = -0.45, throttle = 0.0
# Sending steering = -0.25, throttle = 0.0
# Sending steering = -0.24, throttle = 0.0
# Sending steering = -0.22, throttle = 1.0
# Sending steering = -0.27, throttle = 1.0
# Sending steering = -0.23, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.2, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.14, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.22, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.14, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.14, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.24, throttle = 1.0
# Sending steering = -0.28, throttle = 1.0
# Sending steering = -0.24, throttle = 1.0
# Sending steering = -0.25, throttle = 1.0
# Sending steering = -0.23, throttle = 1.0
# Sending steering = -0.23, throttle = 1.0
# Sending steering = -0.29, throttle = 1.0
# Sending steering = -0.35, throttle = 1.0
# Sending steering = -0.34, throttle = 1.0
# Sending steering = -0.32, throttle = 1.0
# Sending steering = -0.3, throttle = 1.0
# Sending steering = -0.31, throttle = 1.0
# Sending steering = -0.33, throttle = 1.0
# Sending steering = -0.35, throttle = 1.0
# Sending steering = -0.34, throttle = 1.0
# Sending steering = -0.33, throttle = 1.0
# Sending steering = -0.31, throttle = 1.0
# Sending steering = -0.32, throttle = 1.0
# Sending steering = -0.25, throttle = 1.0
# Sending steering = -0.25, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.21, throttle = 1.0
# Sending steering = -0.2, throttle = 1.0
# Sending steering = -0.22, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.2, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.21, throttle = 1.0
# Sending steering = -0.2, throttle = 1.0
# Sending steering = -0.13, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.23, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.14, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.11, throttle = 1.0
# Sending steering = -0.14, throttle = 1.0
# Sending steering = -0.1, throttle = 1.0
# Sending steering = -0.09, throttle = 1.0
# Sending steering = -0.09, throttle = 1.0
# Sending steering = -0.11, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.08, throttle = 1.0
# Sending steering = -0.07, throttle = 1.0
# Sending steering = -0.05, throttle = 1.0
# Sending steering = -0.08, throttle = 1.0
# Sending steering = -0.1, throttle = 1.0
# Sending steering = -0.11, throttle = 1.0
# Sending steering = -0.22, throttle = 1.0
# Sending steering = -0.24, throttle = 1.0
# Sending steering = -0.26, throttle = 1.0
# Sending steering = -0.25, throttle = 1.0
# Sending steering = -0.32, throttle = 1.0
# Sending steering = -0.3, throttle = 1.0
# Sending steering = -0.32, throttle = 1.0
# Sending steering = -0.12, throttle = 1.0
# Sending steering = -0.06, throttle = 1.0
# Sending steering = -0.03, throttle = 1.0
# Sending steering = -0.02, throttle = 1.0
# Sending steering = -0.02, throttle = 1.0
# Sending steering = -0.02, throttle = 1.0
# Sending steering = -0.06, throttle = 1.0
# Sending steering = -0.09, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.13, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.11, throttle = 1.0
# Sending steering = -0.09, throttle = 1.0
# Sending steering = -0.26, throttle = 1.0
# Sending steering = -0.35, throttle = 1.0
# Sending steering = -0.34, throttle = 1.0
# Sending steering = -0.32, throttle = 1.0
# Sending steering = -0.29, throttle = 1.0
# Sending steering = -0.25, throttle = 1.0
# Sending steering = -0.21, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.18, throttle = 0.0
# Sending steering = -0.23, throttle = 0.0
# Sending steering = -0.25, throttle = 0.0
# Sending steering = -0.25, throttle = 0.0
# Sending steering = -0.24, throttle = 0.0
# Sending steering = -0.23, throttle = 0.0
# Sending steering = -0.21, throttle = 0.0
# Sending steering = -0.21, throttle = 0.0
# Sending steering = -0.2, throttle = 0.0
# Sending steering = -0.2, throttle = 0.0
# Sending steering = -0.2, throttle = 0.0
# Sending steering = -0.19, throttle = 0.0
# Sending steering = -0.18, throttle = 0.0
# Sending steering = -0.18, throttle = 0.0
# Sending steering = -0.18, throttle = 0.0
# Sending steering = -0.18, throttle = 0.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.22, throttle = 1.0
# Sending steering = -0.25, throttle = 1.0
# Sending steering = -0.25, throttle = 1.0
# Sending steering = -0.24, throttle = 1.0
# Sending steering = -0.2, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.16, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.2, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.14, throttle = 0.0
# Sending steering = -0.18, throttle = 0.0
# Sending steering = -0.2, throttle = 0.0
# Sending steering = -0.19, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.19, throttle = 0.0
# Sending steering = -0.19, throttle = 0.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.2, throttle = 1.0
# Sending steering = -0.22, throttle = 1.0
# Sending steering = -0.21, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.18, throttle = 0.0
# Sending steering = -0.21, throttle = 0.0
# Sending steering = -0.21, throttle = 0.0
# Sending steering = -0.21, throttle = 0.0
# Sending steering = -0.19, throttle = 0.0
# Sending steering = -0.19, throttle = 0.0
# Sending steering = -0.21, throttle = 0.0
# Sending steering = -0.2, throttle = 0.0
# Sending steering = -0.22, throttle = 0.0
# Sending steering = -0.23, throttle = 0.0
# Sending steering = -0.26, throttle = 1.0
# Sending steering = -0.24, throttle = 1.0
# Sending steering = -0.21, throttle = 1.0
# Sending steering = -0.22, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.2, throttle = 1.0
# Sending steering = -0.23, throttle = 1.0
# Sending steering = -0.23, throttle = 0.0
# Sending steering = -0.22, throttle = 0.0
# Sending steering = -0.24, throttle = 0.0
# Sending steering = -0.26, throttle = 0.0
# Sending steering = -0.31, throttle = 0.0
# Sending steering = -0.33, throttle = 0.0
# Sending steering = -0.3, throttle = 0.0
# Sending steering = -0.24, throttle = 0.0
# Sending steering = -0.21, throttle = 0.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.22, throttle = 1.0
# Sending steering = -0.22, throttle = 1.0
# Sending steering = -0.22, throttle = 1.0
# Sending steering = -0.22, throttle = 1.0
# Sending steering = -0.21, throttle = 1.0
# Sending steering = -0.2, throttle = 1.0
# Sending steering = -0.25, throttle = 1.0
# Sending steering = -0.2, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.21, throttle = 1.0
# Sending steering = -0.24, throttle = 0.0
# Sending steering = -0.32, throttle = 0.0
# Sending steering = -0.39, throttle = 0.0
# Sending steering = -0.55, throttle = 0.0
# Sending steering = -0.8, throttle = 0.0
# Sending steering = -0.61, throttle = 0.0
# Sending steering = -0.38, throttle = 0.0
# Sending steering = -0.48, throttle = 0.0
# Sending steering = -0.47, throttle = 0.0
# Sending steering = -0.27, throttle = 0.0
# Sending steering = -0.28, throttle = 1.0
# Sending steering = -0.28, throttle = 1.0
# Sending steering = -0.24, throttle = 1.0
# Sending steering = -1.07, throttle = 1.0
# Sending steering = -0.77, throttle = 1.0
# Sending steering = -0.8, throttle = 1.0
# Sending steering = -0.56, throttle = 1.0
# Sending steering = -0.4, throttle = 1.0
# Sending steering = -0.46, throttle = 1.0
# Sending steering = -0.56, throttle = 1.0
# Sending steering = -0.6, throttle = 0.0
# Sending steering = -0.81, throttle = 0.0
# Sending steering = -0.63, throttle = 0.0
# Sending steering = -0.39, throttle = 0.0
# Sending steering = -0.41, throttle = 0.0
# Sending steering = -0.49, throttle = 0.0
# Sending steering = -0.67, throttle = 0.0
# Sending steering = -0.34, throttle = 0.0
# Sending steering = -0.0, throttle = 0.0
# Sending steering = 0.06, throttle = 0.0
# Sending steering = 0.22, throttle = 0.0
# Sending steering = 0.48, throttle = 1.0
# Sending steering = 0.42, throttle = 1.0
# Sending steering = -0.05, throttle = 1.0
# Sending steering = -0.91, throttle = 1.0
# Sending steering = -1.65, throttle = 1.0
# Sending steering = -1.94, throttle = 1.0
# Sending steering = -2.13, throttle = 1.0
# Sending steering = -2.08, throttle = 1.0
# Sending steering = -2.04, throttle = 1.0
# Sending steering = -2.08, throttle = 1.0
# Sending steering = -1.68, throttle = 1.0
# Sending steering = -0.48, throttle = 1.0
# Sending steering = 1.67, throttle = 1.0
# Sending steering = 3.82, throttle = 0.0
# Sending steering = 6.86, throttle = 0.0
# Sending steering = 7.57, throttle = 0.0
# Sending steering = 7.68, throttle = 0.0
# Sending steering = 8.01, throttle = 0.0
# Sending steering = 8.56, throttle = 0.0
# Sending steering = 8.12, throttle = 0.0
# Sending steering = 5.03, throttle = 0.0
# Sending steering = 1.51, throttle = 0.0
# Sending steering = 0.19, throttle = 0.0
# Sending steering = -1.0, throttle = 0.0
# Sending steering = -1.21, throttle = 0.0
# Sending steering = -1.57, throttle = 1.0
# Sending steering = -1.33, throttle = 1.0
# Sending steering = -2.09, throttle = 1.0
# Sending steering = -2.05, throttle = 1.0
# Sending steering = -2.88, throttle = 1.0
# Sending steering = -3.32, throttle = 1.0
# Sending steering = -2.22, throttle = 1.0
# Sending steering = -0.42, throttle = 1.0
# Sending steering = 0.15, throttle = 1.0
# Sending steering = -0.1, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.2, throttle = 0.0
# Sending steering = -0.2, throttle = 0.0
# Sending steering = -0.19, throttle = 0.0
# Sending steering = -0.19, throttle = 0.0
# Sending steering = -0.19, throttle = 0.0
# Sending steering = -0.18, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.13, throttle = 0.0
# Sending steering = -0.13, throttle = 0.0
# Sending steering = -0.13, throttle = 0.0
# Sending steering = -0.12, throttle = 1.0
# Sending steering = -0.13, throttle = 1.0
# Sending steering = -0.13, throttle = 1.0
# Sending steering = -0.13, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.21, throttle = 1.0
# Sending steering = -0.21, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.19, throttle = 0.0
# Sending steering = -0.18, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.16, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.19, throttle = 0.0
# Sending steering = -0.18, throttle = 0.0
# Sending steering = -0.18, throttle = 0.0
# Sending steering = -0.18, throttle = 0.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.14, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.18, throttle = 0.0
# Sending steering = -0.21, throttle = 0.0
# Sending steering = -0.23, throttle = 0.0
# Sending steering = -0.22, throttle = 0.0
# Sending steering = -0.21, throttle = 0.0
# Sending steering = -0.21, throttle = 0.0
# Sending steering = -0.21, throttle = 0.0
# Sending steering = -0.21, throttle = 0.0
# Sending steering = -0.2, throttle = 0.0
# Sending steering = -0.21, throttle = 0.0
# Sending steering = -0.22, throttle = 0.0
# Sending steering = -0.23, throttle = 1.0
# Sending steering = -0.25, throttle = 1.0
# Sending steering = -0.26, throttle = 1.0
# Sending steering = -0.29, throttle = 1.0
# Sending steering = -0.26, throttle = 1.0
# Sending steering = -0.27, throttle = 1.0
# Sending steering = -0.28, throttle = 1.0
# Sending steering = -0.26, throttle = 1.0
# Sending steering = -0.23, throttle = 1.0
# Sending steering = -0.25, throttle = 1.0
# Sending steering = -0.24, throttle = 1.0
# Sending steering = -0.21, throttle = 0.0
# Sending steering = -0.22, throttle = 0.0
# Sending steering = -0.24, throttle = 0.0
# Sending steering = -0.23, throttle = 0.0
# Sending steering = -0.23, throttle = 0.0
# Sending steering = -0.24, throttle = 0.0
# Sending steering = -0.26, throttle = 0.0
# Sending steering = -0.27, throttle = 0.0
# Sending steering = -0.26, throttle = 0.0
# Sending steering = -0.21, throttle = 0.0
# Sending steering = -0.22, throttle = 0.0
# Sending steering = -0.2, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.21, throttle = 1.0
# Sending steering = -0.23, throttle = 1.0
# Sending steering = -0.2, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.17, throttle = 0.0
# Sending steering = -0.19, throttle = 0.0
# Sending steering = -0.22, throttle = 0.0
# Sending steering = -0.26, throttle = 0.0
# Sending steering = -0.27, throttle = 0.0
# Sending steering = -0.27, throttle = 0.0
# Sending steering = -0.23, throttle = 0.0
# Sending steering = -0.21, throttle = 0.0
# Sending steering = -0.28, throttle = 0.0
# Sending steering = -0.27, throttle = 0.0
# Sending steering = -0.24, throttle = 1.0
# Sending steering = -0.31, throttle = 1.0
# Sending steering = -0.29, throttle = 1.0
# Sending steering = -0.3, throttle = 1.0
# Sending steering = -0.2, throttle = 1.0
# Sending steering = -0.26, throttle = 1.0
# Sending steering = -0.22, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.07, throttle = 1.0
# Sending steering = 0.01, throttle = 1.0
# Sending steering = 0.03, throttle = 0.0
# Sending steering = -0.22, throttle = 0.0
# Sending steering = -0.52, throttle = 0.0
# Sending steering = -0.29, throttle = 0.0
# Sending steering = -0.23, throttle = 0.0
# Sending steering = -0.22, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.13, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.13, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.2, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.13, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.13, throttle = 1.0
# Sending steering = -0.21, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.12, throttle = 1.0
# Sending steering = -0.13, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.23, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.2, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.14, throttle = 1.0
# Sending steering = -0.12, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.21, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.12, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.14, throttle = 1.0
# Sending steering = -0.21, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.11, throttle = 1.0
# Sending steering = -0.1, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.2, throttle = 1.0
# Sending steering = -0.13, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.13, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.13, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.12, throttle = 1.0
# Sending steering = -0.12, throttle = 1.0
# Sending steering = -0.12, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.11, throttle = 1.0
# Sending steering = -0.13, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.14, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.12, throttle = 1.0
# Sending steering = -0.13, throttle = 1.0
# Sending steering = -0.14, throttle = 1.0
# Sending steering = -0.13, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.2, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.16, throttle = 1.0
# Sending steering = -0.14, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.17, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.14, throttle = 1.0
# Sending steering = -0.14, throttle = 1.0
# Sending steering = -0.15, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.19, throttle = 1.0
# Sending steering = -0.18, throttle = 1.0
# Sending steering = -0.2, throttle = 1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-2f151cb0229a> in <module>
#      30         car_controls.throttle = 0.0
#      31
# ---> 32     image_buf[0] = get_image()
#      33     state_buf[0] = np.array([car_controls.steering, car_controls.throttle, car_controls.brake, car_state.speed])
#      34     model_output = model.predict([image_buf, state_buf])
#
# <ipython-input-3-2f151cb0229a> in get_image()
#      17 state_buf = np.zeros((1,4))
#      18 def get_image():
# ---> 19     image_response = client.simGetImages([ImageRequest(0, AirSimImageType.Scene, False, False)])[0]
#      20     image1d = np.fromstring(image_response.image_data_uint8, dtype=np.uint8)
#      21     image_rgba = image1d.reshape(image_response.height, image_response.width, 3)
#
# H:\Anaconda3\envs\tf22_gan\lib\site-packages\airsim\client.py in simGetImages(self, requests, vehicle_name)
#     293             list[ImageResponse]:
#     294         """
# --> 295         responses_raw = self.client.call("simGetImages", requests, vehicle_name)
#     296         return [
#     297             ImageResponse.from_msgpack(response_raw) for response_raw in responses_raw
#
# H:\Anaconda3\envs\tf22_gan\lib\site-packages\msgpackrpc\session.py in call(self, method, *args)
#      39
#      40     def call(self, method, *args):
# ---> 41         return self.send_request(method, args).get()
#      42
#      43     def call_async(self, method, *args):
#
# H:\Anaconda3\envs\tf22_gan\lib\site-packages\msgpackrpc\future.py in get(self)
#      23
#      24     def get(self):
# ---> 25         self.join()
#      26
#      27         assert self._set_flag == True
#
# H:\Anaconda3\envs\tf22_gan\lib\site-packages\msgpackrpc\future.py in join(self)
#      20     def join(self):
#      21         while (not self._set_flag):
# ---> 22             self._loop.start()
#      23
#      24     def get(self):
#
# H:\Anaconda3\envs\tf22_gan\lib\site-packages\msgpackrpc\loop.py in start(self)
#      20         """
#      21
# ---> 22         self._ioloop.start()
#      23
#      24     def stop(self):
#
# H:\Anaconda3\envs\tf22_gan\lib\site-packages\tornado\ioloop.py in start(self)
#     861
#     862                 try:
# --> 863                     event_pairs = self._impl.poll(poll_timeout)
#     864                 except Exception as e:
#     865                     # Depending on python version and IOLoop implementation,
#
# H:\Anaconda3\envs\tf22_gan\lib\site-packages\tornado\platform\select.py in poll(self, timeout)
#      60
#      61     def poll(self, timeout):
# ---> 62         readable, writeable, errors = select.select(
#      63             self.read_fds, self.write_fds, self.error_fds, timeout)
#      64         events = {}
#
# KeyboardInterrupt:

# %%
car_controls.throttle = -0.5
car_controls.steering = 0
client.setCarControls(car_controls)

# %% [markdown]
# Next, we'll load the model and connect to AirSim Simulator in the Landscape environment. Please ensure that the simulator is running in a different process *before* kicking this step off.

# %%
model = load_model(MODEL_PATH)

client = CarClient()
client.confirmConnection()
client.enableApiControl(True)
car_controls = CarControls()
print('Connection established!')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-abfe90f3be35> in <module>
#       1 model = load_model(MODEL_PATH)
#       2
# ----> 3 client = CarClient()
#       4 client.confirmConnection()
#       5 client.enableApiControl(True)
#
# J:\AutonomousDrivingCookbook\AirSimE2EDeepLearning\AirSimClient.py in __init__(self, ip)
#     504         if (ip == ""):
#     505             ip = "127.0.0.1"
# --> 506         super(CarClient, self).__init__(ip, 42451)
#     507
#     508     def setCarControls(self, controls):
#
# J:\AutonomousDrivingCookbook\AirSimE2EDeepLearning\AirSimClient.py in __init__(self, ip, port)
#     148 class AirSimClientBase:
#     149     def __init__(self, ip, port):
# --> 150         self.client = msgpackrpc.Client(msgpackrpc.Address(ip, port), timeout = 3600)
#     151
#     152     def ping(self):
#
# H:\Anaconda3\envs\tf22_gan\lib\site-packages\msgpackrpc\client.py in __init__(self, address, timeout, loop, builder, reconnect_limit, pack_encoding, unpack_encoding)
#      13
#      14         if timeout:
# ---> 15             loop.attach_periodic_callback(self.step_timeout, 1000) # each 1s
#      16
#      17     @classmethod
#
# H:\Anaconda3\envs\tf22_gan\lib\site-packages\msgpackrpc\loop.py in attach_periodic_callback(self, callback, callback_time)
#      36             self.dettach_periodic_callback()
#      37
# ---> 38         self._periodic_callback = ioloop.PeriodicCallback(callback, callback_time, self._ioloop)
#      39         self._periodic_callback.start()
#      40
#
# TypeError: __init__() takes 3 positional arguments but 4 were given

# %% [markdown]
# We'll set the initial state of the car, as well as some buffers used to store the output from the model

# %%
car_controls.steering = 0
car_controls.throttle = 0
car_controls.brake = 0

image_buf = np.zeros((1, 59, 255, 3))
state_buf = np.zeros((1,4))

# %% [markdown]
# We'll define a helper function to read a RGB image from AirSim and prepare it for consumption by the model

# %%
def get_image():
    image_response = client.simGetImages([ImageRequest(0, AirSimImageType.Scene, False, False)])[0]
    image1d = np.fromstring(image_response.image_data_uint8, dtype=np.uint8)
    image_rgba = image1d.reshape(image_response.height, image_response.width, 4)
    
    return image_rgba[76:135,0:255,0:3].astype(float)

# %% [markdown]
# Finally, a control block to run the car. Because our model doesn't predict speed, we will attempt to keep the car running at a constant 5 m/s. Running the block below will cause the model to drive the car!

# %%
while (True):
    car_state = client.getCarState()
    
    if (car_state.speed < 5):
        car_controls.throttle = 1.0
    else:
        car_controls.throttle = 0.0
    
    image_buf[0] = get_image()
    state_buf[0] = np.array([car_controls.steering, car_controls.throttle, car_controls.brake, car_state.speed])
    model_output = model.predict([image_buf, state_buf])
    car_controls.steering = round(0.5 * float(model_output[0][0]), 2)
    
    print('Sending steering = {0}, throttle = {1}'.format(car_controls.steering, car_controls.throttle))
    
    client.setCarControls(car_controls)

# %% [markdown]
# ## Observations and Future Experiments
#
# We did it! The car is driving around nicely on the road, keeping to the right side for the most part, carefully navigating all the sharp turns and instances where it could potentially go off the road. However, you would immediately notice a few other things. Firstly, the motion of the car is not smooth, especially on those bridges. Also, if you let the model running for a while (a little more than 5 minutes), you will notice that the car eventually veers off the road randomly and crashes. But that is nothing to be disheartened by! Keep in mind that we have barely scratched the surface of the possibilities here. The fact that were able to have the car learn to drive around almost perfectly using a very small dataset is something to be proud of!
#
# > **Thought Exercise 2.1**:
# As you might have noticed, the motion of the car is not very smooth on those bridges. Can you think of a reason why it is so? Can you use one of the techniques we described in Step 0 to fix this?
#
# > ** Thought Exercise 2.2**:
# The car seems to crash when it tries to climb one of those hills. Can you think of a reason why? How can you fix this? (Hint: You might want to take a look at what the car is seeing when it is making that ascent)
#
# AirSim opens up a world of possibilities. There is no limit to the new things you can try as you train even more complex models and use other learning techniques. Here are a few immediate things you could try that might require modifying some of the code provided in this tutorial (including the helper files) but won't require modifying any Unreal assets.
#
# > ** Exploratory Idea 2.1**:
# If you have a background in Machine Learning, you might have asked the question: why did we train and test in the same environment? Isn't that overfitting? Well, you can make arguments on both sides. While using the same environment for both training and testing might seem like you are overfitting to that environment, it can also be seen as drawing examples from the same probability distribution. The data used for training and testing is not the same, even though it is coming from the same distribution. So that brings us to the question: how will this model fare in a different environment, one it hasn't seen before?
# This current model will probably not do very well, given that the other available environments are very different and contain elements that this model has never seen before (intersections, traffic, buildings etc.). But it would be unfair to ask this model to work well on those environments. Think of it like a human who has only ever driven in the mountains, never seen other cars or intersections in their entire life, is suddenly asked to drive in a city. How well do you think they will fare?
# The opposite case should be interesting though. Does training on data collected from one of the city environments generalize easily to driving in the mountains? Try it yourself to find out.
#
# > ** Exploratory Idea 2.2**:
# We formulated this problem as a regression problem - we are predicting a continuous valued variable. Instead, we could formulate the problem as a classification problem. More specifically, we could define buckets for the steering angles (..., -0.1, -0.05, 0, 0.05, 0.1, ...), bucketize the labels, and predict the correct bucket for each image. What happens if we make this change?
#
# > ** Exploratory Idea 2.3**:
# The model currently views a single image and a single state for each prediction. However, we have access to historical data. Can we extend the model to make predictions using the previous N images and states (e.g. given the past 3 images and past 3 states, predict the next steering angle)? (Hint: This will possibly require you to use recurrent neural network techniques)
#
# > ** Exploratory Idea 2.4**:
# AirSim is a lot more than the dataset we provided you. For starters, we only used one camera and used it only in RGB mode. AirSim lets you collect data in depth view, segmentation view, surface normal view etc for each of the cameras available. So you can potentially have 20 different images (for 5 cameras operating in all 4 modes) for each instance (we only used 1 image here). How can combining all this information help us improve the model we just trained?
